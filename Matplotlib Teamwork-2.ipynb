# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
labels = ['UK', 'USA', 'GER', 'JAP', 'FRA']
age_men = [40, 35, 45, 53, 28]
age_women = [35, 32, 48, 48, 31]

# %%
fig, ax = plt.subplots(figsize=(10,6), dpi=100)
x_pos = np.arange(len(labels))  
width = 0.4 
men_graph = ax.bar(x,age_men,width,label="Men")
ax.set_ylabel('Ages')
ax.set_title('Ages means by gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)

def topvalue(y_value):
    for i in y_value:
        value = i.get_height()
        ax.annotate("{}".format(value),xy=(i.get_x() + i.get_width() / 2, value),
                    xytext=(0, 3),textcoords="offset points",ha='center',va='bottom')
topvalue(men_graph)

ax.legend(loc=1);

# %%
fig, ax = plt.subplots(figsize=(10,6), dpi=100)
x_pos = np.arange(len(labels))  
width = 0.4 
women_graph = ax.bar(x_pos,age_women,width,label="Women")
ax.set_ylabel('Ages')
ax.set_title('Ages means by gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)

def topvalue(y_value):
    for i in y_value:
        value = i.get_height()
        ax.annotate("{}".format(value),xy=(i.get_x() + i.get_width() / 2, value),
                    xytext=(0, 3),textcoords="offset points",ha='center',va='bottom')
topvalue(women_graph)

ax.legend(loc=1);

# %%
fig, ax = plt.subplots(figsize=(10,6), dpi=100)
x_pos = np.arange(len(labels))  
width = 0.4 
men_graph = ax.bar(x_pos,age_men,width,label="Men")
women_graph = ax.bar(x_pos,age_women,width,label="Women")
ax.set_ylabel('Ages')
ax.set_title('Ages means by gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc=1);

# %%
fig, ax = plt.subplots(figsize=(10,6), dpi=100)
x_pos = np.arange(len(labels))  
width = 0.4 
men_graph = ax.bar(x_pos - width/2,age_men,width,label="Men")
women_graph = ax.bar(x_pos + width/2,age_women,width,label="Women")
ax.set_ylabel('Ages')
ax.set_title('Ages means by gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)

def topvalue(y_value):
    for i in y_value:
        value = i.get_height()
        ax.annotate("{}".format(value),xy=(i.get_x() + i.get_width()/2, value),
                    xytext=(0, 3),textcoords="offset points",ha='center',va='bottom')
topvalue(men_graph)
topvalue(women_graph)

ax.legend(loc=1);
