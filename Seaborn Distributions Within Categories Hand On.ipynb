# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.boxplot(data=df, y="math score");

# %%
sns.boxplot(data=df, y="math score", x="test preparation course");

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.boxplot(data=df, y="math score", x="test preparation course");

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.boxplot(data=df, y="reading score", x="test preparation course");

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.boxplot(data=df, y="reading score", x="parental level of education");

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.boxplot(data=df, y="reading score", x="parental level of education", hue="test preparation course");

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.boxplot(data=df, y="reading score", x="parental level of education", hue="test preparation course")
plt.legend(bbox_to_anchor=(1.05,0.5));

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.boxplot(data=df, y="parental level of education", x="reading score", hue="test preparation course")
plt.legend(bbox_to_anchor=(1.05,0.5));

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.boxplot(data=df, y="parental level of education", x="reading score", hue="test preparation course",palette="Set2")
plt.legend(bbox_to_anchor=(1.05,0.5));

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.violinplot(data=df, y="parental level of education", x="reading score")
#plt.legend(bbox_to_anchor=(1.05,0.5));
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='parental level of education'>

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.violinplot(data=df, y="parental level of education", x="reading score",hue="test preparation course",palette="Set2")
plt.legend(bbox_to_anchor=(1.2,0.5));

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.violinplot(data=df, y="parental level of education", x="reading score",hue="test preparation course",palette="Set2",split=True)
plt.legend(bbox_to_anchor=(1.2,0.5));

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.violinplot(data=df, y="parental level of education", x="reading score",hue="test preparation course",palette="Set2",split=True,inner=None)
plt.legend(bbox_to_anchor=(1.2,0.5));

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.violinplot(data=df, y="parental level of education", x="reading score",hue="test preparation course",palette="Set2",split=True,inner="quartile")
plt.legend(bbox_to_anchor=(1.2,0.5));

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.violinplot(data=df, y="parental level of education", x="reading score",hue="test preparation course",palette="Set2",split=True,inner="stick")
plt.legend(bbox_to_anchor=(1.2,0.5));

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.violinplot(data=df, y="parental level of education", x="reading score",bw=0.1)
plt.legend(bbox_to_anchor=(1.2,0.5));
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.violinplot(data=df, y="parental level of education", x="reading score",bw=0.01)
plt.legend(bbox_to_anchor=(1.2,0.5));
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(10,8),dpi=100)
sns.violinplot(data=df, y="parental level of education", x="reading score",bw=0.7)
plt.legend(bbox_to_anchor=(1.2,0.5));
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.swarmplot(data=df,x="math score");
# Out:
# C:\Users\Ertuğrul\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.swarmplot(data=df,x="math score",size=2);

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.swarmplot(data=df,x="math score",y="gender",size=2);

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.swarmplot(data=df,x="math score",y="gender",size=2,hue="test preparation course")
plt.legend(bbox_to_anchor=(1.22,0.5));

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.swarmplot(data=df,x="math score",y="gender",size=2,hue="test preparation course",dodge=True)
plt.legend(bbox_to_anchor=(1.22,0.5));

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.boxenplot(x="math score",y="test preparation course",data=df);

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.boxenplot(x="math score",y="test preparation course",data=df,hue="gender");

# %%
plt.figure(figsize=(8,4),dpi=100)
sns.boxplot(x="math score",y="test preparation course",data=df,hue="gender");
